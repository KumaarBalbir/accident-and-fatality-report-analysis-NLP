# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Read data

# %%
data = pd.read_excel('/content/drive/MyDrive/Coal10_2010_2015.xlsx', sheet_name="MERGED_COAL10")
data
# Out:
#      Accident Code         Accident Reason       Date      Time Time Range  \
# 0              111           Fall of Roof  2010-01-02  12:00:00       0-8
# 1              111           Fall of Roof  2010-02-24  13:30:00       0-8
# 2              111           Fall of Roof  2010-03-20  09:45:00       0-8
# 3              111           Fall of Roof  2010-04-03  14:40:00       0-8
# 4              111           Fall of Roof  2010-04-16  11:30:00       0-8
# ..             ...                     ...        ...       ...        ...
# 460            991     Irruption of Water  2015-04-06  12:04:00       0-8
# 461            993      Drowning in Water  2015-03-01  07:55:00       0-8
# 462            993      Drowning in Water  2015-06-21  14:00:00       0-8
# 463            993      Drowning in Water  2015-10-15  08:03:00       0-8
# 464            994  Buried in Sands, etc.  2015-06-24  09:00:00       0-8
#
#               State                           Mine    District  \
# 0       West Bengal                     SHANKARPUR     Burdwan
# 1    Madhya Pradesh                       BARTARAI     Anuppur
# 2      Chhattisgarh                  BALGI PROJECT       Korba
# 3    Madhya Pradesh                    BIRSINGHPUR      Umaria
# 4      Chhattisgarh  RAJGAMAR 1&2 (PAWAN INCLINE )    Bilaspur
# ..              ...                            ...         ...
# 460       Telangana           SRIRAMPUR NO.3 & 3 A    Adilabad
# 461       Jharkhand                    BASANTIMATA     Dhanbad
# 462     Maharashtra               CHANDA RAYATWARI  Chandrapur
# 463         Gujarat    SURKHA(NORTH) LIGNITE MINE,  Bhavanagar
# 464       Telangana             SRIRAMPUR OCP, SRP    Adilabad
#
#                                Owner Company  No. of persons died along  \
# 0                    Eastern Coalfields Ltd.                          0
# 1              South Eastern Coalfields Ltd.                          0
# 2              South Eastern Coalfields Ltd.                          0
# 3              South Eastern Coalfields Ltd.                          0
# 4              South Eastern Coalfields Ltd.                          0
# ..                                       ...                        ...
# 460        Singareni Collieries Company Ltd.                          0
# 461                  Bharat Coking Coal Ltd.                          0
# 462                  Western Coalfields Ltd.                          0
# 463  Gujarat Mineral Development Corpn. Ltd.                          0
# 464        Singareni Collieries Company Ltd.                          0
#
#            Name of person Occupation of the person Gender of the person  \
# 0              Ismail Mia                  Dresser                 Male
# 1              Poshan Das           Support Mistry                 Male
# 2               Dhani Ram        Explosive Carrier                 Male
# 3                Daya Ram            Roof Stitcher                 Male
# 4             Kitab Singh                 Cableman                 Male
# ..                    ...                      ...                  ...
# 460  Pesaru Satyanarayana            Mining Sirdar                 Male
# 461    Manoranjan Pradhan        Shovel Optr( Con)                 Male
# 462   Sarnath Bapu Dhoble                 Engineer                 Male
# 463  Paresh Kr. Samantray                    Agent                 Male
# 464       Merugu Srikanth         Contract Workman                 Male
#
#      Age of the person Age Range  \
# 0                   40       <50
# 1                   44       <50
# 2                   47       <50
# 3                   56       >50
# 4                   40       <50
# ..                 ...       ...
# 460                 51       >50
# 461                 26      <30
# 462                 55       >50
# 463                 42       <50
# 464                 28      <30
#
#                                                 Reason  \
# 0    While a dresser was engaged for dressing coal ...
# 1    While a driller was pulling a drilling cable a...
# 2    While an explosive carrier in stooping positio...
# 3    While a roof stitcher was drinking water from ...
# 4    While SDL reached the junction of split and or...
# ..                                                 ...
# 460  While a mining sirdar was walking along a dip ...
# 461  While a shovel was deployed for working on an ...
# 462  While an engineer went alone at the sump area ...
# 463  While an agent-cum-manager of the mine during ...
# 464  While a group of eight contractor's work perso...
#
#                                                 Remedy  Shift SubShifts
# 0    Had the roof of the gallery been made and kept...      2        1C
# 1    Had the roof of the working place been made an...      2        1D
# 2    Had i) the person carefully examined his worki...      2        1B
# 3    Had the roof of the gallery been made and kept...      2        2A
# 4    Had i) the working place been carefully examin...      2        1C
# ..                                                 ...    ...       ...
# 460                                                  -      2        1D
# 461  Had i) the system of dividing the mine into 4 ...      1        1A
# 462  Had the deceased not gone alone near the under...      2        1D
# 463  Had the person during inspection of opencast w...      2        1B
# 464  Had i) the spilled coal been not allowed to ac...      2        1B
#
# [465 rows x 19 columns]

# %% [markdown]
# # Data Clearning

# %%
data['Age Range'].value_counts()
# Out:
# <50     211
# >50     158
# <30      96
# Name: Age Range, dtype: int64

# %%
def shift(hr):
  if(hr == 24 or hr<8):
    return 3
  if(hr<16):
    return 1
  return 2

# %%
def sub_shift(hr):
  s = (hr%8)//2
  di = {0:'A', 1:'B', 2:'C', 3:'D'}
  return f'{shift(hr)}{di[s]}'

# %%
data['Date'] =  pd.to_datetime(data['Date']) + pd.to_timedelta((data['Time'].astype(str)))
data['SubShifts'] = (data['Date'].dt.hour).apply(sub_shift)
data['Shift'] = (data['Date'].dt.hour).apply(shift)

# %%
def range_fun(x):
  if(x<30):
    return 'age <30'
  if(x<50):
      return '30<= age <50'
  return 'age >= 50'

# %%
data['Age Range'] = data['Age of the person'].apply(range_fun)

# %%
data['Accident Group'] = data['Accident Code'] //100

# %%
data['Month'] = data['Date'].dt.month_name()

# %%
data['Day'] = data['Date'].dt.day

# %%
data = data.drop(columns = {'Time','Gender of the person', 'Time Range', 'No. of persons died along'}, axis = 1)

# %%
#Standardising company names
import re
data["Owner Company"] = data["Owner Company"].map(lambda x: re.sub(r"Lt$|Ltd$|LTD.$|LTD$|LT$|Lt.$", "Ltd.", x))
data["Owner Company"] = data["Owner Company"].map(lambda x: re.sub(r"Limited|Limite|LIMITED", "Ltd.", x))
data["Owner Company"] = data["Owner Company"].map(lambda x: re.sub(r"Coalfields$|Coalfield$", "Coalfields Ltd.", x))
data["Owner Company"] = data["Owner Company"].map(lambda x: re.sub(r"M/S ", "M/s.", x))

# %%
data
# Out:
#      Accident Code         Accident Reason                Date  \
# 0              111           Fall of Roof  2010-01-02 12:00:00
# 1              111           Fall of Roof  2010-02-24 13:30:00
# 2              111           Fall of Roof  2010-03-20 09:45:00
# 3              111           Fall of Roof  2010-04-03 14:40:00
# 4              111           Fall of Roof  2010-04-16 11:30:00
# ..             ...                     ...                 ...
# 460            991     Irruption of Water  2015-04-06 12:04:00
# 461            993      Drowning in Water  2015-03-01 07:55:00
# 462            993      Drowning in Water  2015-06-21 14:00:00
# 463            993      Drowning in Water  2015-10-15 08:03:00
# 464            994  Buried in Sands, etc.  2015-06-24 09:00:00
#
#               State                           Mine    District  \
# 0       West Bengal                     SHANKARPUR     Burdwan
# 1    Madhya Pradesh                       BARTARAI     Anuppur
# 2      Chhattisgarh                  BALGI PROJECT       Korba
# 3    Madhya Pradesh                    BIRSINGHPUR      Umaria
# 4      Chhattisgarh  RAJGAMAR 1&2 (PAWAN INCLINE )    Bilaspur
# ..              ...                            ...         ...
# 460       Telangana           SRIRAMPUR NO.3 & 3 A    Adilabad
# 461       Jharkhand                    BASANTIMATA     Dhanbad
# 462     Maharashtra               CHANDA RAYATWARI  Chandrapur
# 463         Gujarat    SURKHA(NORTH) LIGNITE MINE,  Bhavanagar
# 464       Telangana             SRIRAMPUR OCP, SRP    Adilabad
#
#                                Owner Company        Name of person  \
# 0                    Eastern Coalfields Ltd.            Ismail Mia
# 1              South Eastern Coalfields Ltd.            Poshan Das
# 2              South Eastern Coalfields Ltd.             Dhani Ram
# 3              South Eastern Coalfields Ltd.              Daya Ram
# 4              South Eastern Coalfields Ltd.           Kitab Singh
# ..                                       ...                   ...
# 460        Singareni Collieries Company Ltd.  Pesaru Satyanarayana
# 461                  Bharat Coking Coal Ltd.    Manoranjan Pradhan
# 462                  Western Coalfields Ltd.   Sarnath Bapu Dhoble
# 463  Gujarat Mineral Development Corpn. Ltd.  Paresh Kr. Samantray
# 464        Singareni Collieries Company Ltd.       Merugu Srikanth
#
#     Occupation of the person  Age of the person     Age Range  \
# 0                    Dresser                 40  30<= age <50
# 1             Support Mistry                 44  30<= age <50
# 2          Explosive Carrier                 47  30<= age <50
# 3              Roof Stitcher                 56     age >= 50
# 4                   Cableman                 40  30<= age <50
# ..                       ...                ...           ...
# 460            Mining Sirdar                 51     age >= 50
# 461        Shovel Optr( Con)                 26       age <30
# 462                 Engineer                 55     age >= 50
# 463                    Agent                 42  30<= age <50
# 464         Contract Workman                 28       age <30
#
#                                                 Reason  \
# 0    While a dresser was engaged for dressing coal ...
# 1    While a driller was pulling a drilling cable a...
# 2    While an explosive carrier in stooping positio...
# 3    While a roof stitcher was drinking water from ...
# 4    While SDL reached the junction of split and or...
# ..                                                 ...
# 460  While a mining sirdar was walking along a dip ...
# 461  While a shovel was deployed for working on an ...
# 462  While an engineer went alone at the sump area ...
# 463  While an agent-cum-manager of the mine during ...
# 464  While a group of eight contractor's work perso...
#
#                                                 Remedy  Shift SubShifts  \
# 0    Had the roof of the gallery been made and kept...      1        1C
# 1    Had the roof of the working place been made an...      1        1C
# 2    Had i) the person carefully examined his worki...      1        1A
# 3    Had the roof of the gallery been made and kept...      1        1D
# 4    Had i) the working place been carefully examin...      1        1B
# ..                                                 ...    ...       ...
# 460                                                  -      1        1C
# 461  Had i) the system of dividing the mine into 4 ...      3        3D
# 462  Had the deceased not gone alone near the under...      1        1D
# 463  Had the person during inspection of opencast w...      1        1A
# 464  Had i) the spilled coal been not allowed to ac...      1        1A
#
#      Accident Group     Month  Day
# 0                 1   January    2
# 1                 1  February   24
# 2                 1     March   20
# 3                 1     April    3
# 4                 1     April   16
# ..              ...       ...  ...
# 460               9     April    6
# 461               9     March    1
# 462               9      June   21
# 463               9   October   15
# 464               9      June   24
#
# [465 rows x 18 columns]

# %%
print("Number of unique values in each cloumn:")
for col in data.columns:
  print(col, " : ", len(data[col].value_counts()))
# Out:
# Number of unique values in each cloumn:
# Accident Code  :  37
# Accident Reason  :  59
# Date  :  429
# State  :  14
# Mine  :  291
# District  :  42
# Owner Company  :  30
# Name of person  :  460
# Occupation of the person  :  232
# Age of the person  :  42
# Age Range  :  3
# Reason  :  429
# Remedy  :  417
# Shift  :  3
# SubShifts  :  12
# Accident Group  :  9
# Month  :  12
# Day  :  31

# %% [markdown]
# # EDA

# %% [markdown]
# ## Analysing the deaths

# %% [markdown]
# ### Creating a function to plot the features against deaths recorded

# %%
deaths = data[["Date", "State", "District", "Owner Company", "Mine", "Accident Group", 'Age Range']].groupby(["Date", "Age Range", "State", "District", "Accident Group", "Owner Company", "Mine"], as_index=False).size().reset_index()
deaths["Month"] = deaths.Date.dt.month_name()
deaths["Day"] = deaths.Date.dt.day

def plot_against_death(col, chart_type="bar"):
  fig, ax = plt.subplots(figsize=(18, 8))
  ax.tick_params(axis='both', which='major', labelsize=12) 
  ax.tick_params(axis='both', which='minor', labelsize=12)
  deathvcol = deaths[[col, "Accident Group", "index"]].groupby([col, "Accident Group"], as_index=False).count()
  deathvcol = deathvcol.pivot(columns="Accident Group", index=col).fillna(0)
  deathvcol.plot(kind=chart_type, stacked=True, ax=ax)
  ax.set_ylabel("Deaths", fontsize=14)
  ax.set_xlabel(col, fontsize=14)
  ax.set_title(col + "-wise Death Count", fontsize=18)
  ax.legend(["Ground Movement",
            "Transportation Machinery (winding)",
            "Transportation Machinery (non-winding)",
            "Machinery other than transportation machinery",
            "Explosives",
            "Electricity",
            "Dust, gas and other combustible material",
            "Falls (other than fall of ground)",
            "Other causes"], 
            bbox_to_anchor=(1,1), 
            fontsize=15)

# %% [markdown]
# ### deaths vs. state

# %%
plot_against_death("State")

# %% [markdown]
# ### death vs owner company

# %%
plot_against_death("Owner Company")

# %% [markdown]
# ### Deaths vs Month

# %%
plot_against_death("Month", chart_type="line")

# %% [markdown]
# ### Deaths vs day of the month

# %%
plot_against_death("Day", chart_type="line")

# %% [markdown]
# ### deaths vs age group

# %%
plot_against_death("Age Range")

# %% [markdown]
# # importing spacy for nlp

# %%
# !python3 -m spacy download

# %%
import spacy

try:
  nlp = spacy.load("en_core_web_lg")
except:
  # !python3 -m spacy download en_core_web_lg
  nlp = spacy.load("en_core_web_lg")

# %%
doc = nlp("dog hates cat")
for token in doc:
  print(token.text, token.pos_, token.dep_)

# %%
def extract_noun(txt):
  doc = nlp(txt)
  sub = []
  for token in doc:
    if token.pos_ == "NOUN":
      sub.append(token)
  return sub

# %%
data["Remedy"] = data.Remedy.astype("str")
data["Reason"] = data.Reason.astype("str")

# %%
def extract_verb(txt):
  doc = nlp(txt)
  sub = []
  for token in doc:
    if token.pos_ == "VERB":
      sub.append(token)
  return sub

# %%
data["Remedy"] = data.Remedy.astype("str")
data["Remedy Nouns"] = data.Remedy.map(lambda x: extract_noun(x))
data["Remedy Verb"] = data.Remedy.map(lambda x: extract_verb(x))
data["Reason Nouns"] = data.Reason.map(lambda x: extract_noun(x))
data["Reason Verbs"] = data.Reason.map(lambda x: extract_verb(x))

# %%
data
